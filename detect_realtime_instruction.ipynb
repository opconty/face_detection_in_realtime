# %%
import cv2
import os
from keras.models import load_model
from config import *
from utils import get_yolo_boxes, draw_boxes
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = ''
model = load_model(weights_name)
# Out:
# /home/gaolijun/anaconda3/lib/python3.6/site-packages/keras/engine/saving.py:270: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
# for testing
img_path = r'./images/img_test.jpg'
image = cv2.imread(img_path)
plt.imshow(image[...,::-1])

# %%
boxes = get_yolo_boxes(model, [image], net_h, net_w, anchors, obj_thresh, nms_thresh)[0]
print(len(boxes))
image_c0 = draw_boxes(image, boxes, obj_thresh)
plt.imshow(image_c0[...,::-1])
# Out:
# 22

# %%
image_c1 = draw_boxes(image, boxes, obj_thresh, rect=False)  # eclipse
plt.imshow(image_c1[...,::-1])
